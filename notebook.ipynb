# %%
# !git push
# Out:
# Username for 'https://github.com': ^C

# %%
# !wget https://i.postimg.cc/GtKZb2sQ/mask.png
# Out:
# --2021-04-30 01:13:33--  https://i.postimg.cc/GtKZb2sQ/mask.png
# Resolving i.postimg.cc (i.postimg.cc)... 104.238.220.13
# Connecting to i.postimg.cc (i.postimg.cc)|104.238.220.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 766491 (749K) [image/png]
# Saving to: 'mask.png'
#
# mask.png            100%[===================>] 748.53K   681KB/s    in 1.1s
#
# 2021-04-30 01:13:35 (681 KB/s) - 'mask.png' saved [766491/766491]

# %%
# !python app_v2.py -s rtsp://admin:QPPZFE@192.168.100.98:554/H.264_stream -v 2
# Out:
# 2021-04-30 01:24:30.453703: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /workspace/pull_frame_youtube/load_model/tensorflow_loader.py:17: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /workspace/pull_frame_youtube/load_model/tensorflow_loader.py:18: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
